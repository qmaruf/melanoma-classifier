# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = np.load('../input/x_train_224.npy')

# %%
len(data)
# Out:
# 33126

# %%
plt.imshow(data[0])

# %%
df = pd.read_csv('../input/train_folds.csv')

# %%
df.shape
# Out:
# (33126, 10)

# %%
df.kfold.hist()
# Out:
# <AxesSubplot:>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=33126, step=1)

# %%
df
# Out:
#        Unnamed: 0    image_name  patient_id     sex  age_approx  \
# 0               0  ISIC_4062017  IP_8385941  female        50.0
# 1               1  ISIC_2751294  IP_1230004    male        15.0
# 2               2  ISIC_4672131  IP_7199022  female        70.0
# 3               3  ISIC_7593978  IP_9290101  female        40.0
# 4               4  ISIC_7783447  IP_2636470  female        50.0
# ...           ...           ...         ...     ...         ...
# 33121       33121  ISIC_7539588  IP_5805281    male        50.0
# 33122       33122  ISIC_1944865  IP_5889408  female        45.0
# 33123       33123  ISIC_9097916  IP_6526534    male        50.0
# 33124       33124  ISIC_6819137  IP_6332843    male        25.0
# 33125       33125  ISIC_3230575  IP_9770302  female        55.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  kfold
# 0                             torso   unknown           benign       0      0
# ...

# %%
fold = 1
df_train = df[df.kfold != fold]
df_valid = df[df.kfold == fold]

# %%
df[df.kfold==fold].target.index
# Out:
# Int64Index([ 6623,  6624,  6625,  6626,  6628,  6629,  6630,  6631,  6632,
#              6633,
#             ...
#             13241, 13242, 13243, 13244, 13245, 13246, 13247, 13248, 13249,
#             13250],
#            dtype='int64', length=6625)

# %%
df_valid
# Out:
#        Unnamed: 0    image_name  patient_id     sex  age_approx  \
# 6623         6623  ISIC_3066463  IP_9355893    male        55.0
# 6624         6624  ISIC_0668165  IP_2442926  female        65.0
# 6625         6625  ISIC_3556983  IP_4558019    male        60.0
# 6626         6626  ISIC_1781826  IP_0148851  female        60.0
# 6628         6628  ISIC_9369222  IP_5872065    male        50.0
# ...           ...           ...         ...     ...         ...
# 13246       13246  ISIC_0872845  IP_3938557    male        30.0
# 13247       13247  ISIC_2046223  IP_1226635    male        45.0
# 13248       13248  ISIC_4770938  IP_3690477    male        60.0
# 13249       13249  ISIC_5110209  IP_1517386    male        40.0
# 13250       13250  ISIC_1904579  IP_1470733    male        70.0
#
#       anatom_site_general_challenge diagnosis benign_malignant  target  kfold
# 6623                upper extremity   unknown           benign       0      1
# ...
